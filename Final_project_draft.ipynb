# %% [markdown]
# <a href="https://colab.research.google.com/github/heelafakher/Data-Scientist/blob/main/Final_project_draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load the dataset
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('https://raw.githubusercontent.com/heelafakher/Data-Scientist/main/data_Scientist_cleaned_2021.csv')
df
# find the correct datatype for each columns 
df.info
df.dtypes
# Out:
#      index                                          Job Title  \
# 0        0                                     Data Scientist
# 1        1                          Healthcare Data Scientist
# 2        2                                     Data Scientist
# 3        3                                     Data Scientist
# 4        4                                     Data Scientist
# ..     ...                                                ...
# 737    950           Sr Scientist, Immuno-Oncology - Oncology
# 738    951                               Senior Data Engineer
# 739    952  Project Scientist - Auton Lab, Robotics Institute
# 740    953                               Data Science Manager
# 741    955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  Rating  \
# 0     $53K-$91K (Glassdoor est.)     3.8
# 1    $63K-$112K (Glassdoor est.)     3.4
# 2     $80K-$90K (Glassdoor est.)     4.8
# 3     $56K-$97K (Glassdoor est.)     3.8
# 4    $86K-$143K (Glassdoor est.)     2.9
# ..                           ...     ...
# 737  $58K-$111K (Glassdoor est.)     3.9
# 738  $72K-$133K (Glassdoor est.)     4.4
# 739   $56K-$91K (Glassdoor est.)     2.6
# 740  $95K-$160K (Glassdoor est.)     3.2
# 741  $61K-$126K (Glassdoor est.)     3.6
#
#                                    Company Name         Location  Founded  \
# 0                        Tecolote Research\n3.8  Albuquerque, NM     1973
# 1    University of Maryland Medical System\n3.4    Linthicum, MD     1984
# 2                                  KnowBe4\n4.8   Clearwater, FL     2010
# 3                                     PNNL\n3.8     Richland, WA     1965
# 4                       Affinity Solutions\n2.9     New York, NY     1998
# ..                                          ...              ...      ...
# 737                                    GSK\n3.9    Cambridge, MA     1830
# 738                             Eventbrite\n4.4    Nashville, TN     2006
# 739         Software Engineering Institute\n2.6   Pittsburgh, PA     1984
# 740                           Numeric, LLC\n3.2    Allentown, PA       -1
# 741           Riverside Research Institute\n3.6  Beavercreek, OH     1967
#
#           Type of ownership  Lower Salary  Upper Salary  Avg Salary
# 0         Company - Private            53            91        72.0
# 1        Other Organization            63           112        87.5
# 2         Company - Private            80            90        85.0
# 3                Government            56            97        76.5
# 4         Company - Private            86           143       114.5
# ..                      ...           ...           ...         ...
# 737        Company - Public            58           111        84.5
# 738        Company - Public            72           133       102.5
# 739    College / University            56            91        73.5
# 740       Company - Private            95           160       127.5
# 741  Nonprofit Organization            61           126        93.5
#
# [742 rows x 11 columns]

# %%
## finding for each columns of dataset mean, meadian and mode
mean_upper_salary = df['Upper Salary'].mean()
median_upper_salary = df['Upper Salary'].median()
mode_upper_salary = df['Upper Salary'].mode()
print("upper salary mean is :",mean_upper_salary )
print("upper salary median is :",median_upper_salary)
print("upper salary mode is:",mode_upper_salary )
# Out:
# upper salary mean is : 128.21428571428572
# upper salary median is : 124.0
# upper salary mode is: 0    140
# Name: Upper Salary, dtype: int64

# %%
mean_lower_salary = df['Lower Salary'].mean()
median_lower_salary = df['Lower Salary'].median()
mode_lower_salary = df['Lower Salary'].mode()
print("lower salary mean is :",mean_lower_salary )
print("lower salary median is :", median_lower_salary)
print("lower Salary mode is:", mode_lower_salary )
# Out:
# lower salary mean is : 74.75471698113208
# lower salary median is : 69.5
# lower Salary mode is: 0    43
# Name: Lower Salary, dtype: int64

# %%
# for finding mean, median and mode for salary estimate just need to change the data type
mean_esti_salary = df['Salary Estimate'].mean()
median_esti_salary = df['Salary Estimate'].median()
mode_esti_salary = df['Salary Estimate'].mode()
print("estimate salary mean is :",mean_esti_salary )
print("estimate salary median is :", median_esti_salary)
print("estimate  Salary mode is:",mode_esti_salary)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1629         try:
# -> 1630             x = float(x)
#    1631         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '$53K-$91K (Glassdoor est.)$63K-$112K (Glassdoor est.)$80K-$90K (Glassdoor est.)$56K-$97K (Glassdoor est.)$86K-$143K (Glassdoor est.)$71K-$119K (Glassdoor est.)$54K-$93K (Glassdoor est.)$86K-$142K (Glassdoor est.)$38K-$84K (Glassdoor est.)$120K-$160K (Glassdoor est.)$126K-$201K (Glassdoor est.)$64K-$106K (Glassdoor est.)$106K-$172K (Glassdoor est.)$46K-$85K (Glassdoor est.)$83K-$144K (Glassdoor est.)$102K-$190K (Glassdoor est.)$67K-$137K (Glassdoor est.)$118K-$189K (Glassdoor est.)$110K-$175K (Glassdoor est.)$64K-$111K (Glassdoor est.)$81K-$130K (Glassdoor est.)$73K-$119K (Glassdoor est.)$86K-$139K (Glassdoor est.)$63K-$105K (Glassdoor est.)$109K-$177K (Glassdoor est.)$63K-$110K (Glassdoor est.)$75K-$124K (Glassdoor est.)$34K-$61K (Glassdoor est.)$63K-$105K (Glassdoor est.)$80K-$90K (Glassdoor est.)$56K-$97K (Glassdoor est.)$72K-$120K (Glassdoor est.)$86K-$143K (Glassdoor est.)$93K-$149K (Glassdoor est.)$85K-$140K (Glassdoor est.)$77K-$135K (Glassdoor est.)$82K-$132K (Glassdoor est.)$83K-$137K (Glassdoor est.)$115K-$180K (Glassdoor est.)$74K-$138K (Glassdoor est.)$64K-$112K (Glassdoor est.)$68K-$129K (Glassdoor est.)$110K-$175K (Glassdoor est.)$52K-$113K (Glassdoor est.)$110K-$150K(Employer est.)Employer Provided Salary:$150K-$160K$158K-$211K (Glassdoor est.)$20K-$39K (Glassdoor est.)$56K-$117K (Glassdoor est.)$63K-$99K (Glassdoor est.)$68K-$114K (Glassdoor est.)$86K-$143K (Glassdoor est.)$41K-$95K (Glassdoor est.)$...
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1633             try:
# -> 1634                 x = complex(x)
#    1635             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-4a2d1ee18664> in <cell line: 2>()
#       1 # for finding mean, median and mode for salary estimate just need to change the data type
# ----> 2 mean_esti_salary = df['Salary Estimate'].mean()
#       3 median_esti_salary = df['Salary Estimate'].median()
#       4 mode_esti_salary = df['Salary Estimate'].mode()
#       5 print("estimate salary mean is :",mean_esti_salary )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11845             **kwargs,
#   11846         ):
# > 11847             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11848
#   11849         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11399         **kwargs,
#   11400     ) -> Series | float:
# > 11401         return self._stat_function(
#   11402             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   11403         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11351                 name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352             )
# > 11353         return self._reduce(
#   11354             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4814                 )
#    4815             with np.errstate(all="ignore"):
# -> 4816                 return op(delegate, skipna=skipna, **kwds)
#    4817
#    4818     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      91             try:
#      92                 with np.errstate(invalid="ignore"):
# ---> 93                     return f(*args, **kwargs)
#      94             except ValueError as e:
#      95                 # we want to transform an object array
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     153                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154             else:
# --> 155                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     156
#     157             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     416             mask = isna(values)
#     417
# --> 418         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     419
#     420         if datetimelike:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     704
#     705     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 706     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     707
#     708     if axis is not None and getattr(the_sum, "ndim", False):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1635             except ValueError as err:
#    1636                 # e.g. "foo"
# -> 1637                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1638     return x
#    1639
#
# TypeError: Could not convert $53K-$91K (Glassdoor est.)$63K-$112K (Glassdoor est.)$80K-$90K (Glassdoor est.)$56K-$97K (Glassdoor est.)$86K-$143K (Glassdoor est.)$71K-$119K (Glassdoor est.)$54K-$93K (Glassdoor est.)$86K-$142K (Glassdoor est.)$38K-$84K (Glassdoor est.)$120K-$160K (Glassdoor est.)$126K-$201K (Glassdoor est.)$64K-$106K (Glassdoor est.)$106K-$172K (Glassdoor est.)$46K-$85K (Glassdoor est.)$83K-$144K (Glassdoor est.)$102K-$190K (Glassdoor est.)$67K-$137K (Glassdoor est.)$118K-$189K (Glassdoor est.)$110K-$175K (Glassdoor est.)$64K-$111K (Glassdoor est.)$81K-$130K (Glassdoor est.)$73K-$119K (Glassdoor est.)$86K-$139K (Glassdoor est.)$63K-$105K (Glassdoor est.)$109K-$177K (Glassdoor est.)$63K-$110K (Glassdoor est.)$75K-$124K (Glassdoor est.)$34K-$61K (Glassdoor est.)$63K-$105K (Glassdoor est.)$80K-$90K (Glassdoor est.)$56K-$97K (Glassdoor est.)$72K-$120K (Glassdoor est.)$86K-$143K (Glassdoor est.)$93K-$149K (Glassdoor est.)$85K-$140K (Glassdoor est.)$77K-$135K (Glassdoor est.)$82K-$132K (Glassdoor est.)$83K-$137K (Glassdoor est.)$115K-$180K (Glassdoor est.)$74K-$138K (Glassdoor est.)$64K-$112K (Glassdoor est.)$68K-$129K (Glassdoor est.)$110K-$175K (Glassdoor est.)$52K-$113K (Glassdoor est.)$110K-$150K(Employer est.)Employer Provided Salary:$150K-$160K$158K-$211K (Glassdoor est.)$20K-$39K (Glassdoor est.)$56K-$117K (Glassdoor est.)$63K-$99K (Glassdoor est.)$68K-$114K (Glassdoor est.)$86K-$143K (Glassdoor est.)$41K-$95K (Glassdoor est.)$86K-$144K (Glassdoo...

# %%
mean_index = df['index'].mean()
median_index = df['index'].median()
mode_index   =  df['index'].mode()
print("index mean is :",mean_index)
print("index median is :",median_index )
print("index mode is:",mode_index)
# Out:
# index mean is : 469.12938005390833
# index median is : 472.5
# index mode is: 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 737    950
# 738    951
# 739    952
# 740    953
# 741    955
# Name: index, Length: 742, dtype: int64

# %%
mean_r = df['Rating'].mean()
median_r= df['Rating'].median()
mode_r  = df['Rating'].mode()
print("Rating mean is :",mean_r)
print("Rating median is :",median_r)
print("Rating mode is:",mode_r)
# Out:
# Rating mean is : 3.6188679245283017
# Rating median is : 3.7
# Rating mode is: 0    3.9
# Name: Rating, dtype: float64

# %%
mean_avsalary = df['Avg Salary'].mean()
median_avsalary = df['Avg Salary'].median()
mode_avsalary = df['Avg Salary'].mode()
print("Avg salary mean is :",mean_avsalary)
print("Avg salary median is :",median_avsalary)
print("Avg Salary mode is:",mode_avsalary)

# %%
mean_found = df['Founded'].mean()
median_found= df['Founded'].median()
mode_found = df['Founded'].mode()
print("founded mean is :",mean_found)
print("founded median is :",median_found)
print("founded mode is:",mode_found)
# Out:
# founded mean is : 1837.154986522911
# founded median is : 1988.0
# founded mode is: 0   -1
# Name: Founded, dtype: int64

# %%
# mode of job title
#mean_jobtitle = df['Job Title'].mean()
#median_jobtitle = df['Job Title'].median()
mode_jobtitle = df['Job Title'].mode()
#print("job title mean is :",mean_jobtitle)
#print("job title median is :",median_jobtitle)
print("job title mode is:",mode_jobtitle)
# Out:
# job title mode is: 0    Data Scientist
# Name: Job Title, dtype: object

# %%
#correlation of columns
df.corr()
# Out:
# <ipython-input-53-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                  index    Rating   Founded  Lower Salary  Upper Salary  \
# index         1.000000 -0.140705 -0.081748     -0.046113     -0.027764
# Rating       -0.140705  1.000000  0.332927     -0.009638      0.027332
# Founded      -0.081748  0.332927  1.000000     -0.033732      0.007169
# Lower Salary -0.046113 -0.009638 -0.033732      1.000000      0.939995
# Upper Salary -0.027764  0.027332  0.007169      0.939995      1.000000
# Avg Salary   -0.035750  0.012475 -0.009609      0.978679      0.990032
#
#               Avg Salary
# index          -0.035750
# Rating          0.012475
# Founded        -0.009609
# Lower Salary    0.978679
# Upper Salary    0.990032
# Avg Salary      1.000000

# %%
# Scatter plot of Lower salary vs. upper salary
plt.scatter(df['Upper Salary'],df['Lower Salary'], alpha=0.5)
plt.xlabel('Upper salary')
plt.ylabel('Lower salary')
plt.title('upper salary vs. lower salary')
plt.show()

# Correlation between upper salary and lower salary
correlation = df['Lower Salary'].corr(df['Upper Salary'])
print('Correlation between upper salary and lower salary:', correlation)
# Check if the correlation is significant
if abs(correlation) > 0.9:
    print('The correlation is significant')
else:
    print('The correlation is not significant')
# Out:
# Correlation between upper salary and lower salary: 0.939994789936283
# The correlation is significant

# %%
# Bar gragh of company rating :
company_rating = df.groupby('Company Name')['Rating'].mean()
company_rating.plot(kind ='bar')
plt.xlabel('Company Name')
plt.ylabel('Rating')
plt.title('company rating')
plt.show()
######################################################
#bar gragh for which company has the highest rating:
highest_rating = company_rating.idxmax()
print('company name  with highest rating:',highest_rating)
###################################################
 #bar gragh for which company  has the lowest rating:
lowest_rating = company_rating.idxmin()
print('company name  with lowest rating:',lowest_rating)
# Out:
# company name  with highest rating: BPA Services
# 5.0
# company name  with lowest rating: ALIN

# %%
# Pie chart of avg salary by job title :  still unfinied for this pie chart we need nested pie chart
avgsalary_by_jobtitle = df.groupby('Job Title')['Avg Salary'].sum()
avgsalary_by_jobtitle.plot(kind = 'pie',autopct='%1.1f%%')
plt.title('avg salary via job title')
plt.show()
